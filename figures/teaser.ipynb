# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([0, 1, 3, 4, 7, 8])
v = np.array([95, 80.3, 96.8, 88.8, 83.5, 18.5])
plt.bar(x[::2], v[::2], 1, label='Target-only')
plt.bar(x[1::2], v[1::2], 1, label='Source-only')

labels = [
    'UCF → HMDB',
    'HMDB → UCF',
    'K400 → BABEL',
]
plt.xticks([.5, 3.5, 7.5], labels)

plt.plot([5.5, 5.5], [0, 120], 'k--')
plt.ylim(0, 120)

plt.legend() 

plt.savefig('./teaser.svg')
plt.show()
